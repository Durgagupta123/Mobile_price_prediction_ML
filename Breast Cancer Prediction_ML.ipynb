# %%
#Importing the dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

import warnings
warnings.filterwarnings("ignore")

# %%
#load the file in df
df = pd.read_csv("Breast Cancer.csv")

#to show the first 5 record
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#Delete the unwanted file from the dataset
df.drop("Unnamed: 32",axis=1,inplace=True)
df.drop("id",axis=1,inplace=True)

# %%
#Cross check the columns
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#To check the number of rows and columns
df.shape
# Out:
# (569, 31)

# %%
#Check the null value
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
#Cross check the null value by using datatypes
df.dtypes
# Out:
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# ...

# %%
#Visualise the null value if any
sb.heatmap(df.isnull())
plt.show()

# %%
#To check the duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
#Visualise all the columns using histogram 
sb.pairplot(data=df.iloc[:,:5],hue="diagnosis")
plt.show()

# %%
f = df["diagnosis"].value_counts()
print(f)

#Visualise the diagnosis graphically
sb.countplot(data=df,x="diagnosis")
plt.yticks(f)
plt.show()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#Applying Label Encoder to convert object types data into numerical type data
#Here column diagnosis is object type data , we convert into numeric type data
#call inbuilt class from sklearn package 
from sklearn.preprocessing import LabelEncoder

#create an object for LabelEncoder class
le = LabelEncoder()

#Apply on column diagnosis to convert into number type data
df["diagnosis"] = le.fit_transform(df["diagnosis"])

# %%
f1 = df["diagnosis"].value_counts()
f1
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
#1's indicate the M which is Malignant means Person having the cancer
#0's indicate the B which is Benign means Person not having the cancer

# %%
#To check the values change
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#Show the statistical values
df.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#To check the outlier in our dataset use box plot
plt.figure(figsize=(50,15))
sb.boxplot(data=df)
plt.show()

# %%
#Now select the input and output
x = df.drop("diagnosis",axis=1)    #input selected
y = df["diagnosis"]    #output selected

# %%
#To check x-input and y-output
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
y.sample(5)
# Out:
# 135    1
# 281    0
# 60     0
# 555    0
# 413    0
# Name: diagnosis, dtype: int32

# %%
#Split the model into 70-30% 
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
#To check the number of rows and columns in train - test split
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((398, 30), (171, 30), (398,), (171,))

# %%
#Scale the model by inbuilt class StandardScaler from sklean package
from sklearn.preprocessing import StandardScaler

#create an object for StandardScaler class
ss = StandardScaler()

# %%
#apply on training and testing data
x_train = ss.fit_transform(x_train)
x_test = ss.transform(x_test)

# %%
#To check 
x_train
# Out:
# array([[-0.71883452, -1.0127044 , -0.7245577 , ..., -0.2815459 ,
#         -0.35881004, -0.34607992],
#        [-0.30216665, -0.01934589, -0.37921906, ..., -1.54873267,
#         -0.75672753, -1.24878553],
#        [ 0.01101507,  0.25734302,  0.00800276, ...,  0.28247674,
#         -0.58871793, -0.31697955],
#        ...,
#        [ 0.82801089,  1.1622518 ,  0.86897862, ...,  1.11762396,
#          0.78896085,  2.96839375],
#        [-0.03528136,  0.42063483, -0.09551981, ..., -0.52687039,
#         -1.13342276, -0.4601059 ],
#        [-0.30761329, -0.22119271, -0.37921906, ..., -0.96681402,
#         -1.55609956, -1.32005176]])

# %%
x_test
# Out:
# array([[ 0.14445772, -1.22815887,  0.23756998, ..., -0.06202148,
#         -0.07054093,  0.48476556],
#        [-0.26948682, -0.1667621 , -0.24606217, ...,  1.39948615,
#          1.82708337,  2.01817732],
#        [-0.32939985, -0.76549874, -0.35827747, ..., -0.13957087,
#          0.90745184,  0.70806642],
#        ...,
#        [ 0.44129954, -0.34139362,  0.45014685, ...,  0.98489521,
#          1.63608298,  1.24018762],
#        [-0.3511864 , -0.72240785, -0.38830692, ..., -0.85242867,
#          1.30360081, -0.78971222],
#        [-0.81687402,  0.45692189, -0.839934  , ..., -1.07225135,
#          0.19296888, -0.75348522]])

# %%
#Now we apply Classification Algorithm to our dataset
#we create the user define function
def create_model(model):
    model.fit(x_train,y_train)   #to train the dataset into 70% data
    y_pred = model.predict(x_test)  #to test the data on 30% data
    
    #generate report
    print(classification_report(y_test,y_pred))
    print(confusion_matrix(y_test,y_pred))
    
    return model

# %%
#call the inbuilt class 
from sklearn.metrics import classification_report , confusion_matrix

# %%
#call the inbuilt class 
from sklearn.metrics import classification_report , confusion_matrix



#1. Classification Alogithm : Base Line Model 
#means Logistic Regression 
from sklearn.linear_model import LogisticRegression

#create an object for LogisticRegreesion class
lr = LogisticRegression()

#call the function
lr = create_model(lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       108
#            1       0.95      0.97      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171
#
# [[105   3]
#  [  2  61]]

# %%
#2.Classifiaction Algorithm : DecisionTreeClassifier by default it takes GINI Index
#create an object for DecisionTreeClassifier class
from sklearn.tree import DecisionTreeClassifier

#create an object for DecisionTreeClassifier class
dtc = DecisionTreeClassifier(random_state=1)

#call the function
dtc = create_model(dtc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       108
#            1       1.00      0.81      0.89        63
#
#     accuracy                           0.93       171
#    macro avg       0.95      0.90      0.92       171
# weighted avg       0.94      0.93      0.93       171
#
# [[108   0]
#  [ 12  51]]

# %%
#To check the Information Gain :
dict1 = {"Input":x.columns,"IG":dtc.feature_importances_}
df2 = pd.DataFrame(dict1)
df2.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.765758
# 1             texture_worst  0.099478
# 2              radius_worst  0.051849
# 3       concave points_mean  0.022228
# 4      concave points_worst  0.020767
# 5           smoothness_mean  0.010646
# 6   fractal_dimension_worst  0.009655
# 7      fractal_dimension_se  0.008940
# 8          smoothness_worst  0.007152
# 9                   area_se  0.003528
# 10        concave points_se  0.000000
# 11           symmetry_worst  0.000000
# 12          concavity_worst  0.000000
# 13        compactness_worst  0.000000
# 14               area_worst  0.000000
# 15              symmetry_se  0.000000
# 16              radius_mean  0.000000
# 17             concavity_se  0.000000
# 18             texture_mean  0.000000
# 19            smoothness_se  0.000000
# 20             perimeter_se  0.000000
# 21               texture_se  0.000000
# 22                radius_se  0.000000
# 23   fractal_dimension_mean  0.000000
# ...

# %%
#To Draw the tree , we call the inbuilt method tree from sklearn package
from sklearn import tree

f = x.columns
plt.figure(figsize=(10,10))
_ = tree.plot_tree(dtc,feature_names=f,filled=True)
plt.show()

# %%
#Here we got the recall score 0.81(81%) which is good , but not better 
#So for better score we apply pruning technique on our dataset
#There are 2 types of Pruning technique
#1.Max Depth : get the best between >=1 to <=8
#2.Min Samples Leaf : get the best score between >=45 to <=100

# %%
#1.max_depth : applying for-loop to check the best score
for i in range(1,9):
    dtc1 = DecisionTreeClassifier(random_state=1,max_depth=i)
    print("Max Depth :",i)
    #call the function
    dtc1 = create_model(dtc1)
# Out:
# Max Depth : 1
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       108
#            1       0.77      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.85       171
# weighted avg       0.86      0.85      0.86       171
#
# [[92 16]
#  [ 9 54]]
# Max Depth : 2
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       108
#            1       0.84      0.78      0.81        63
#
#     accuracy                           0.87       171
#    macro avg       0.86      0.85      0.85       171
# weighted avg       0.86      0.87      0.86       171
#
# [[99  9]
#  [14 49]]
# Max Depth : 3
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       108
#            1       0.86      0.90      0.88        63
#
# ...

# %%
#Got the best score at 3 , to check
dtc1 = DecisionTreeClassifier(random_state=1,max_depth=3)
#call the function
dtc1 = create_model(dtc1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       108
#            1       0.86      0.90      0.88        63
#
#     accuracy                           0.91       171
#    macro avg       0.90      0.91      0.91       171
# weighted avg       0.91      0.91      0.91       171
#
# [[99  9]
#  [ 6 57]]

# %%
#To check the Information Gain :
dict2 = {"Input":x.columns,"IG":dtc1.feature_importances_}
df3 = pd.DataFrame(dict2)
df3.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.851610
# 1             texture_worst  0.098153
# 2       concave points_mean  0.024002
# 3      concave points_worst  0.022425
# 4                   area_se  0.003810
# 5               radius_mean  0.000000
# 6              concavity_se  0.000000
# 7            symmetry_worst  0.000000
# 8           concavity_worst  0.000000
# 9         compactness_worst  0.000000
# 10         smoothness_worst  0.000000
# 11               area_worst  0.000000
# 12             radius_worst  0.000000
# 13     fractal_dimension_se  0.000000
# 14              symmetry_se  0.000000
# 15        concave points_se  0.000000
# 16           compactness_se  0.000000
# 17             texture_mean  0.000000
# 18            smoothness_se  0.000000
# 19             perimeter_se  0.000000
# 20               texture_se  0.000000
# 21                radius_se  0.000000
# 22   fractal_dimension_mean  0.000000
# 23            symmetry_mean  0.000000
# ...

# %%
#2.Min Samples Leaf : 2nd pruning technique apply for loop check the best score
for i in range(45,101):
    dtc2 = DecisionTreeClassifier(random_state=1,min_samples_leaf=i)
    print("Min Samples Leaf :",i)
    #call the function
    dtc2 = create_model(dtc2)
# Out:
# Min Samples Leaf : 45
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       108
#            1       0.77      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.85       171
# weighted avg       0.86      0.85      0.86       171
#
# [[92 16]
#  [ 9 54]]
# Min Samples Leaf : 46
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       108
#            1       0.77      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.85       171
# weighted avg       0.86      0.85      0.86       171
#
# [[92 16]
#  [ 9 54]]
# Min Samples Leaf : 47
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       108
#            1       0.77      0.86      0.81        63
#
# ...

# %%
#Get the good score at 45 , to show
dtc2 = DecisionTreeClassifier(random_state=1,min_samples_leaf=45)
#call the function
dtc2 = create_model(dtc2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       108
#            1       0.77      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.85       171
# weighted avg       0.86      0.85      0.86       171
#
# [[92 16]
#  [ 9 54]]

# %%
#To check the Information Gain :
dict3 = {"Input":x.columns,"IG":dtc2.feature_importances_}
df4 = pd.DataFrame(dict3)
df4.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.933977
# 1            concavity_mean  0.057811
# 2       concave points_mean  0.008034
# 3      concave points_worst  0.000178
# 4               radius_mean  0.000000
# 5              concavity_se  0.000000
# 6            symmetry_worst  0.000000
# 7           concavity_worst  0.000000
# 8         compactness_worst  0.000000
# 9          smoothness_worst  0.000000
# 10               area_worst  0.000000
# 11            texture_worst  0.000000
# 12             radius_worst  0.000000
# 13     fractal_dimension_se  0.000000
# 14              symmetry_se  0.000000
# 15        concave points_se  0.000000
# 16           compactness_se  0.000000
# 17             texture_mean  0.000000
# 18            smoothness_se  0.000000
# 19                  area_se  0.000000
# 20             perimeter_se  0.000000
# 21               texture_se  0.000000
# 22                radius_se  0.000000
# 23   fractal_dimension_mean  0.000000
# ...

# %%
#Using DecisionTreeClassifier , got the recall score 0.81(81%)
#while applying pruning technique
#1.max_depth : got the recall score 0.90(90%)
#2.min_samples_leaf : got the recall score 0.86(86%)

# %%
#3.Now we apply DecisionTreeClassifier with Entropy Index
#create an object for DecisionTreeClassifier class with entropy index
dtc_entropy = DecisionTreeClassifier(random_state=1,criterion="entropy")
#call the function
dtc_entropy = create_model(dtc_entropy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93       108
#            1       0.89      0.87      0.88        63
#
#     accuracy                           0.91       171
#    macro avg       0.91      0.90      0.91       171
# weighted avg       0.91      0.91      0.91       171
#
# [[101   7]
#  [  8  55]]

# %%
#draw a tree for entropy index
plt.figure(figsize=(15,15))
_ = tree.plot_tree(dtc_entropy,feature_names=f,filled=True)
plt.show()

# %%
#To check the Information Gain :
dict4 = {"Input":x.columns,"IG":dtc_entropy.feature_importances_}
df5 = pd.DataFrame(dict4)
df5.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.683724
# 1      concave points_worst  0.147630
# 2             texture_worst  0.056487
# 3                 radius_se  0.025144
# 4          smoothness_worst  0.024350
# 5              perimeter_se  0.023550
# 6              radius_worst  0.022051
# 7                   area_se  0.017064
# 8               radius_mean  0.000000
# 9         concave points_se  0.000000
# 10           symmetry_worst  0.000000
# 11          concavity_worst  0.000000
# 12        compactness_worst  0.000000
# 13               area_worst  0.000000
# 14     fractal_dimension_se  0.000000
# 15              symmetry_se  0.000000
# 16           compactness_se  0.000000
# 17             concavity_se  0.000000
# 18             texture_mean  0.000000
# 19            smoothness_se  0.000000
# 20               texture_se  0.000000
# 21   fractal_dimension_mean  0.000000
# 22            symmetry_mean  0.000000
# 23      concave points_mean  0.000000
# ...

# %%
#Applying pruning technique on DecisionTreeClassifier with entropy index
#1. Max Depth :instead of hit and trail method we use create a for loop to check the best score 
for i in range(1,9):
    dtc_entropy_max = DecisionTreeClassifier(random_state=1,criterion="entropy",max_depth=i)
    print("Max Depth :",i)
    #call the function
    dtc_entropy_max = create_model(dtc_entropy_max)
# Out:
# Max Depth : 1
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87       108
#            1       0.76      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.84       171
# weighted avg       0.85      0.85      0.85       171
#
# [[91 17]
#  [ 9 54]]
# Max Depth : 2
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90       108
#            1       0.92      0.71      0.80        63
#
#     accuracy                           0.87       171
#    macro avg       0.89      0.84      0.85       171
# weighted avg       0.88      0.87      0.87       171
#
# [[104   4]
#  [ 18  45]]
# Max Depth : 3
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       108
#            1       0.81      0.89      0.85        63
#
# ...

# %%
#Got the good score at 3 , to show
dtc_entropy_max = DecisionTreeClassifier(random_state=1,criterion="entropy",max_depth=3)
#call the function
dtc_entropy_max = create_model(dtc_entropy_max)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       108
#            1       0.81      0.89      0.85        63
#
#     accuracy                           0.88       171
#    macro avg       0.87      0.88      0.88       171
# weighted avg       0.89      0.88      0.88       171
#
# [[95 13]
#  [ 7 56]]

# %%
#To check the Information Gain :
dict5 = {"Input":x.columns,"IG":dtc_entropy_max.feature_importances_}
df6 = pd.DataFrame(dict5)
df6.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.752303
# 1      concave points_worst  0.142506
# 2             texture_worst  0.062153
# 3              radius_worst  0.024263
# 4                   area_se  0.018776
# 5               radius_mean  0.000000
# 6              concavity_se  0.000000
# 7            symmetry_worst  0.000000
# 8           concavity_worst  0.000000
# 9         compactness_worst  0.000000
# 10         smoothness_worst  0.000000
# 11               area_worst  0.000000
# 12     fractal_dimension_se  0.000000
# 13              symmetry_se  0.000000
# 14        concave points_se  0.000000
# 15           compactness_se  0.000000
# 16             texture_mean  0.000000
# 17            smoothness_se  0.000000
# 18             perimeter_se  0.000000
# 19               texture_se  0.000000
# 20                radius_se  0.000000
# 21   fractal_dimension_mean  0.000000
# 22            symmetry_mean  0.000000
# 23      concave points_mean  0.000000
# ...

# %%
#Min Samples Leaf : 2nd pruning technique , apply for loop to check best score
for i in range(45,101):
    dtc_entropy_min = DecisionTreeClassifier(random_state=1,criterion="entropy",min_samples_leaf=i)
    print("Min Samples Leaf :",i)
    #call the function
    dtc_entropy_min = create_model(dtc_entropy_min)
# Out:
# Min Samples Leaf : 45
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87       108
#            1       0.76      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.84       171
# weighted avg       0.85      0.85      0.85       171
#
# [[91 17]
#  [ 9 54]]
# Min Samples Leaf : 46
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87       108
#            1       0.76      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.84       171
# weighted avg       0.85      0.85      0.85       171
#
# [[91 17]
#  [ 9 54]]
# Min Samples Leaf : 47
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87       108
#            1       0.76      0.86      0.81        63
#
# ...

# %%
#got the good score at 45
dtc_entropy_min = DecisionTreeClassifier(random_state=1,criterion="entropy",min_samples_leaf=45)
#call the function
dtc_entropy_min = create_model(dtc_entropy_min)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87       108
#            1       0.76      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.84       171
# weighted avg       0.85      0.85      0.85       171
#
# [[91 17]
#  [ 9 54]]

# %%
#To check the Information Gain :
dict6 = {"Input":x.columns,"IG":dtc_entropy_min.feature_importances_}
df7 = pd.DataFrame(dict6)
df7.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.843245
# 1      concave points_worst  0.120686
# 2       concave points_mean  0.031440
# 3          smoothness_worst  0.004629
# 4               radius_mean  0.000000
# 5              concavity_se  0.000000
# 6            symmetry_worst  0.000000
# 7           concavity_worst  0.000000
# 8         compactness_worst  0.000000
# 9                area_worst  0.000000
# 10            texture_worst  0.000000
# 11             radius_worst  0.000000
# 12     fractal_dimension_se  0.000000
# 13              symmetry_se  0.000000
# 14        concave points_se  0.000000
# 15           compactness_se  0.000000
# 16             texture_mean  0.000000
# 17            smoothness_se  0.000000
# 18                  area_se  0.000000
# 19             perimeter_se  0.000000
# 20               texture_se  0.000000
# 21                radius_se  0.000000
# 22   fractal_dimension_mean  0.000000
# 23            symmetry_mean  0.000000
# ...

# %%
#While applying DecisionTreeClassifier with Entropy Index , got the recall score 0.87(87%)
#With Pruning technique :
#1. max_depth : got the recall score is 0.89(89%)
#2. min_samples_leaf : got the recall score 0.86(86%)

# %%
#3.Applying 3rd classification Random Forest Tree by default it take GINI Index
#call the inbuilt class of RandomForestClassifier from sklearn package
from sklearn.ensemble import RandomForestClassifier

# %%
#Create an object for RandomForestClassifier class
#It take no. of estimators means number of iteration means number of decision tree
#we check the best value with n_estimators it should be between >=10 to <=100
#instaed of hit and trial method we use for-loop to find the best n_estiamtors
for i in range(10,101):
    rfc = RandomForestClassifier(n_estimators=i,random_state=1)
    print("No. of Estimators :",i)
    #call the function
    rfc = create_model(rfc)
# Out:
# No. of Estimators : 10
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       108
#            1       0.95      0.92      0.94        63
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.95      0.95       171
# weighted avg       0.95      0.95      0.95       171
#
# [[105   3]
#  [  5  58]]
# No. of Estimators : 11
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       108
#            1       0.94      0.92      0.93        63
#
#     accuracy                           0.95       171
#    macro avg       0.94      0.94      0.94       171
# weighted avg       0.95      0.95      0.95       171
#
# [[104   4]
#  [  5  58]]
# No. of Estimators : 12
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       108
#            1       0.95      0.92      0.94        63
#
# ...

# %%
#Got the good score at 10 , to show
rfc = RandomForestClassifier(n_estimators=10,random_state=1)
#call the function
rfc = create_model(rfc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       108
#            1       0.95      0.92      0.94        63
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.95      0.95       171
# weighted avg       0.95      0.95      0.95       171
#
# [[105   3]
#  [  5  58]]

# %%
#To check the Information Gain :
dict7 = {"Input":x.columns,"IG":rfc.feature_importances_}
df8 = pd.DataFrame(dict7)
df8.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.202474
# 1              radius_worst  0.156135
# 2       concave points_mean  0.150224
# 3                area_worst  0.139770
# 4            concavity_mean  0.082339
# 5            perimeter_mean  0.068779
# 6                 area_mean  0.020360
# 7             texture_worst  0.016686
# 8                   area_se  0.014583
# 9      concave points_worst  0.014487
# 10                radius_se  0.014363
# 11  fractal_dimension_worst  0.013349
# 12          smoothness_mean  0.012273
# 13        compactness_worst  0.011930
# 14          concavity_worst  0.009230
# 15           symmetry_worst  0.008389
# 16             texture_mean  0.008277
# 17         compactness_mean  0.008217
# 18     fractal_dimension_se  0.008005
# 19            symmetry_mean  0.007949
# 20         smoothness_worst  0.007927
# 21              symmetry_se  0.005034
# 22               texture_se  0.004529
# 23        concave points_se  0.004277
# ...

# %%
#Got the recall score 0.92(92%) which is good , but we can do better
#Now apply the pruning technique on RandomForestClassifier
#1.Max Depth : apply loop to check the best score
for i in range(1,9):
    #create an object for RandomForestClassifier class with max_depth
    rfc_max = RandomForestClassifier(n_estimators=10,random_state=1,max_depth=i)
    print("Max Depth :",i)
    #call the function
    rfc_max = create_model(rfc_max)
# Out:
# Max Depth : 1
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       108
#            1       0.88      0.84      0.86        63
#
#     accuracy                           0.90       171
#    macro avg       0.90      0.89      0.89       171
# weighted avg       0.90      0.90      0.90       171
#
# [[101   7]
#  [ 10  53]]
# Max Depth : 2
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92       108
#            1       0.86      0.87      0.87        63
#
#     accuracy                           0.90       171
#    macro avg       0.89      0.89      0.89       171
# weighted avg       0.90      0.90      0.90       171
#
# [[99  9]
#  [ 8 55]]
# Max Depth : 3
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       108
#            1       0.92      0.89      0.90        63
#
# ...

# %%
#Got the good score at 6 , to show
rfc_max = RandomForestClassifier(n_estimators=10,random_state=1,max_depth=6)
#call the function
rtc_max = create_model(rfc_max)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       108
#            1       0.95      0.92      0.94        63
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.95      0.95       171
# weighted avg       0.95      0.95      0.95       171
#
# [[105   3]
#  [  5  58]]

# %%
#To check the Information Gain :
dict8 = {"Input":x.columns,"IG":rfc_max.feature_importances_}
df9 = pd.DataFrame(dict8)
df9.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.203223
# 1              radius_worst  0.156135
# 2       concave points_mean  0.150234
# 3                area_worst  0.139771
# 4            concavity_mean  0.082348
# 5            perimeter_mean  0.068779
# 6                 area_mean  0.020360
# 7             texture_worst  0.015770
# 8                   area_se  0.014591
# 9      concave points_worst  0.014487
# 10                radius_se  0.014369
# 11  fractal_dimension_worst  0.013377
# 12          smoothness_mean  0.012334
# 13        compactness_worst  0.011930
# 14          concavity_worst  0.009259
# 15           symmetry_worst  0.008389
# 16             texture_mean  0.008277
# 17         compactness_mean  0.008217
# 18     fractal_dimension_se  0.008005
# 19            symmetry_mean  0.007949
# 20         smoothness_worst  0.007927
# 21              symmetry_se  0.005047
# 22               texture_se  0.004529
# 23        concave points_se  0.004277
# ...

# %%
#Min Samples Leaf : 2nd pruning technique
for i in range(45,101):
    #create an object for RandomForestClassifier class with min_samples_leaf
    rfc_min = RandomForestClassifier(n_estimators=10,random_state=1,min_samples_leaf=i)
    print("Min Samples Leaf :",i)
    #call the function
    rfc_min = create_model(rfc_min)
# Out:
# Min Samples Leaf : 45
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92       108
#            1       0.87      0.86      0.86        63
#
#     accuracy                           0.90       171
#    macro avg       0.89      0.89      0.89       171
# weighted avg       0.90      0.90      0.90       171
#
# [[100   8]
#  [  9  54]]
# Min Samples Leaf : 46
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       108
#            1       0.89      0.86      0.87        63
#
#     accuracy                           0.91       171
#    macro avg       0.90      0.90      0.90       171
# weighted avg       0.91      0.91      0.91       171
#
# [[101   7]
#  [  9  54]]
# Min Samples Leaf : 47
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       108
#            1       0.89      0.86      0.87        63
#
# ...

# %%
#Got the good score at 45 , to show
rfc_min = RandomForestClassifier(n_estimators=10,random_state=1,min_samples_leaf=45)
#call the function
rtc_min = create_model(rfc_min)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92       108
#            1       0.87      0.86      0.86        63
#
#     accuracy                           0.90       171
#    macro avg       0.89      0.89      0.89       171
# weighted avg       0.90      0.90      0.90       171
#
# [[100   8]
#  [  9  54]]

# %%
#To check the Information Gain :
dict9 = {"Input":x.columns,"IG":rfc_min.feature_importances_}
df10 = pd.DataFrame(dict9)
df10.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.221311
# 1              radius_worst  0.189377
# 2       concave points_mean  0.187243
# 3                area_worst  0.182135
# 4            concavity_mean  0.101976
# 5            perimeter_mean  0.082780
# 6                   area_se  0.009381
# 7              perimeter_se  0.008103
# 8             texture_worst  0.004789
# 9              texture_mean  0.003101
# 10        compactness_worst  0.003009
# 11                radius_se  0.001771
# 12            symmetry_mean  0.001616
# 13          smoothness_mean  0.001361
# 14         compactness_mean  0.001165
# 15        concave points_se  0.000696
# 16     fractal_dimension_se  0.000112
# 17              symmetry_se  0.000060
# 18  fractal_dimension_worst  0.000014
# 19         smoothness_worst  0.000000
# 20     concave points_worst  0.000000
# 21           symmetry_worst  0.000000
# 22          concavity_worst  0.000000
# 23              radius_mean  0.000000
# ...

# %%
#While applying RandomForestClassifier , got the recall score 0.92(92%)
#With Pruning technique :
#1. max_depth : got the recall score is 0.92(92%)
#2. min_samples_leaf : got the recall score 0.86(86%)

# %%
#Aplplying Boosting Technique :
#1.ADA Boost
#2.Gradient Boost
#3.Extreme Gradient Boost (XGB)

# %%
#1.ADA Boost (Adaptor Boosting): call the inbuilt class from sklearn package
from sklearn.ensemble import AdaBoostClassifier

# %%
#create an object for AdaBoostClassifier class 
#It as number of estimators that indicates how many decision stump 
#decision stump means one root node and two child node
#no of estimators are nothing but number of input , so we apply loop to find the best score
#no. of input = 30
for i in range(1,31):
    ada = AdaBoostClassifier(n_estimators=i,random_state=1)
    print("No. of Estimators :",i)
    #call the function
    ada = create_model(ada)
# Out:
# No. of Estimators : 1
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       108
#            1       0.77      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.85       171
# weighted avg       0.86      0.85      0.86       171
#
# [[92 16]
#  [ 9 54]]
# No. of Estimators : 2
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       108
#            1       0.77      0.86      0.81        63
#
#     accuracy                           0.85       171
#    macro avg       0.84      0.85      0.85       171
# weighted avg       0.86      0.85      0.86       171
#
# [[92 16]
#  [ 9 54]]
# No. of Estimators : 3
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90       108
#            1       0.81      0.86      0.83        63
#
# ...

# %%
#Got the good score at 7 , to show
ada = AdaBoostClassifier(n_estimators=7,random_state=1)
#call the function
ada = create_model(ada)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       108
#            1       0.92      0.92      0.92        63
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.94      0.94       171
# weighted avg       0.94      0.94      0.94       171
#
# [[103   5]
#  [  5  58]]

# %%
#To check the Information Gain :
dict10 = {"Input":x.columns,"IG":ada.feature_importances_}
df11 = pd.DataFrame(dict10)
df11.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0                   area_se  0.285714
# 1      concave points_worst  0.142857
# 2          smoothness_worst  0.142857
# 3           perimeter_worst  0.142857
# 4             texture_worst  0.142857
# 5              texture_mean  0.142857
# 6               radius_mean  0.000000
# 7              concavity_se  0.000000
# 8            symmetry_worst  0.000000
# 9           concavity_worst  0.000000
# 10        compactness_worst  0.000000
# 11               area_worst  0.000000
# 12             radius_worst  0.000000
# 13     fractal_dimension_se  0.000000
# 14              symmetry_se  0.000000
# 15        concave points_se  0.000000
# 16           compactness_se  0.000000
# 17            smoothness_se  0.000000
# 18             perimeter_se  0.000000
# 19               texture_se  0.000000
# 20                radius_se  0.000000
# 21   fractal_dimension_mean  0.000000
# 22            symmetry_mean  0.000000
# 23      concave points_mean  0.000000
# ...

# %%
#2. Gradient Boosting : call inbuilt class from sklearn package
from sklearn.ensemble import GradientBoostingClassifier

# %%
#create an object for GradientBoostingClassifier class 
#here we have number of estimators means how many iteration
#mean how many number of decision tree is use to train the model
#we get the good score from n_estimators between >=10 to <=100
#we apply loop instaed of hit and trail method
for i in range(10,101):
    gbc = GradientBoostingClassifier(n_estimators=i,random_state=1)
    print("No. of Estimators :",i)
    #call the function
    gbc = create_model(gbc)
# Out:
# No. of Estimators : 10
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       108
#            1       0.98      0.86      0.92        63
#
#     accuracy                           0.94       171
#    macro avg       0.95      0.92      0.94       171
# weighted avg       0.94      0.94      0.94       171
#
# [[107   1]
#  [  9  54]]
# No. of Estimators : 11
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       108
#            1       1.00      0.87      0.93        63
#
#     accuracy                           0.95       171
#    macro avg       0.97      0.94      0.95       171
# weighted avg       0.96      0.95      0.95       171
#
# [[108   0]
#  [  8  55]]
# No. of Estimators : 12
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       108
#            1       0.96      0.87      0.92        63
#
# ...

# %%
#Got the good score at 19
gbc = GradientBoostingClassifier(n_estimators=19,random_state=1)
#call the function
gbc = create_model(gbc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       108
#            1       0.97      0.92      0.94        63
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# [[106   2]
#  [  5  58]]

# %%
#To check inpormation Gain :
dict11 = {"Input":x.columns,"IG":gbc.feature_importances_}
df12 = pd.DataFrame(dict11)
df12.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.688728
# 1              radius_worst  0.084231
# 2             texture_worst  0.065174
# 3      concave points_worst  0.039566
# 4                area_worst  0.035605
# 5       concave points_mean  0.027774
# 6          smoothness_worst  0.012711
# 7           concavity_worst  0.011761
# 8              texture_mean  0.006976
# 9         concave points_se  0.005677
# 10        compactness_worst  0.004911
# 11                  area_se  0.004189
# 12              symmetry_se  0.003559
# 13     fractal_dimension_se  0.002304
# 14                radius_se  0.001741
# 15              radius_mean  0.001507
# 16           concavity_mean  0.000885
# 17           symmetry_worst  0.000768
# 18           compactness_se  0.000463
# 19            symmetry_mean  0.000447
# 20             perimeter_se  0.000436
# 21           perimeter_mean  0.000324
# 22  fractal_dimension_worst  0.000262
# 23             concavity_se  0.000000
# ...

# %%
#While apply with GradientBoostingClassifier class we got the recall score 0.92(92%)

# %%
#3.Extreme Gradient Boosting (XGB) : call the inbuilt class from xgboost package
from xgboost import XGBClassifier

# %%
#here XGBClassifier class as n_estimators means how many Decision Tree is use for training the model
#n_estimators is >=10 and <=100
for i in range(10,101):
    xgc = XGBClassifier(n_estimators=i,reg_alpha=1,random_state=1)
    print("No. of Estiamtors",i)
    #call function
    xgc = create_model(xgc)
# Out:
# No. of Estiamtors 10
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       108
#            1       0.97      0.89      0.93        63
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.94      0.94       171
# weighted avg       0.95      0.95      0.95       171
#
# [[106   2]
#  [  7  56]]
# No. of Estiamtors 11
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       108
#            1       0.95      0.89      0.92        63
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.93      0.94       171
# weighted avg       0.94      0.94      0.94       171
#
# [[105   3]
#  [  7  56]]
# No. of Estiamtors 12
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       108
#            1       0.95      0.89      0.92        63
#
# ...

# %%
#got the best score at 10
xgc = XGBClassifier(n_estimators=10,reg_alpha=1,random_state=1)
#here reg means regularization and alpha means lambda(constant) means hyperparameter
#reg_alpha=1 , 1 means True means automatically handle the outlier and overfit

#call the function
xgc = create_model(xgc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       108
#            1       0.97      0.89      0.93        63
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.94      0.94       171
# weighted avg       0.95      0.95      0.95       171
#
# [[106   2]
#  [  7  56]]

# %%
#To check inpormation Gain :
dict12 = {"Input":x.columns,"IG":xgc.feature_importances_}
df13 = pd.DataFrame(dict12)
df13.sort_values("IG",ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0           perimeter_worst  0.611317
# 1                area_worst  0.103689
# 2       concave points_mean  0.055963
# 3      concave points_worst  0.050222
# 4              radius_worst  0.041644
# 5             texture_worst  0.030058
# 6          smoothness_worst  0.027024
# 7           concavity_worst  0.022837
# 8              texture_mean  0.020917
# 9         compactness_worst  0.013763
# 10           compactness_se  0.010181
# 11                  area_se  0.003718
# 12              radius_mean  0.002909
# 13           symmetry_worst  0.002697
# 14                radius_se  0.000962
# 15          smoothness_mean  0.000909
# 16             perimeter_se  0.000871
# 17              symmetry_se  0.000321
# 18           concavity_mean  0.000000
# 19           perimeter_mean  0.000000
# 20                area_mean  0.000000
# 21         compactness_mean  0.000000
# 22   fractal_dimension_mean  0.000000
# 23            symmetry_mean  0.000000
# ...

# %%
#Using XGBClassifier got the recall score 0.89(89%)

# %%
#Now we the dataset to Support Vector Machine
#Applying Linear Kernal  function of Support Vector Machine :
#call the inbuilt class of LinearSVC from outer class svm from sklearn package
from sklearn.svm import LinearSVC

# %%
#create an object for LinearSVC class
svc = LinearSVC(random_state=1) #no adding error means support no outlier in our dataset
#it means it's a Hard Margin

#call the function
svc = create_model(svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       108
#            1       0.92      0.97      0.95        63
#
#     accuracy                           0.96       171
#    macro avg       0.95      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# [[103   5]
#  [  2  61]]

# %%
#While apply Support Vector Machine we got the best reacll score whict is 0.97(97)

# %%
#Now we apply KNN Algorithm : 
#call the inbuilt class of KNeighborsClassifier from outer class neighbor from sklearn package
from sklearn.neighbors import KNeighborsClassifier

# %%
#create an object for KNeighborsClassifier class and pass the parameter
knc = KNeighborsClassifier(n_neighbors=5,metric="minkowski",p=2)
#p=2 means apply euclideans distance method 

#call the function
knc = create_model(knc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       108
#            1       0.98      0.90      0.94        63
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# [[107   1]
#  [  6  57]]

# %%
#while applying KNeighborsClassifier class we got the recall score 0.90(90%)

# %%
'''Conclusion : We got the recall score of 97% when we apply Support Vector Machine Classfication
                Algorithm. 
                Which means we use support vector machine algorithm to predict if the person is
                diagnosis with Malignant and Benign means if the person is suffering from the
                cancer or not.'''
